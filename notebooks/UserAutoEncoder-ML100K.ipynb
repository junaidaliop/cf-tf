# %%
import pandas as pd
import numpy as np
import tensorflow as tf

def load_and_preprocess_movielens_100k(base_path='./', delimiter='\t', batch_size=64):
    """
    Load and preprocess the MovieLens 100K dataset for a user-based autoencoder model, including batching,
    ensuring that the TensorFlow datasets are structured to provide (input, target) tuples where input and target are identical.
    
    Args:
        base_path (str): The base path to the dataset files.
        delimiter (str): The delimiter used in the dataset files.
        batch_size (int): The size of batches to produce.
    
    Returns:
        tuple: Contains the number of users, number of movies, TensorFlow dataset for training, and TensorFlow dataset for testing.
    """
    # Load training and testing data
    train_data = pd.read_csv(f'{base_path}movielens_100k_u1.base', sep=delimiter, header=None, names=['user_id', 'movie_id', 'rating', 'timestamp'])
    test_data = pd.read_csv(f'{base_path}movielens_100k_u1.test', sep=delimiter, header=None, names=['user_id', 'movie_id', 'rating', 'timestamp'])

    # Determine the number of users and movies
    num_users = max(train_data['user_id'].max(), test_data['user_id'].max())
    num_movies = max(train_data['movie_id'].max(), test_data['movie_id'].max())

    # Convert to zero-based index for TensorFlow processing
    train_data[['user_id', 'movie_id']] -= 1
    test_data[['user_id', 'movie_id']] -= 1

    # Create matrices
    train_ratings_matrix = np.zeros((num_users, num_movies))
    test_ratings_matrix = np.zeros((num_users, num_movies))

    for row in train_data.itertuples():
        train_ratings_matrix[row.user_id, row.movie_id] = row.rating
    for row in test_data.itertuples():
        test_ratings_matrix[row.user_id, row.movie_id] = row.rating

    # Convert matrices to TensorFlow datasets, ensuring each item is mapped to (input, target) tuple
    train_dataset = tf.data.Dataset.from_tensor_slices((train_ratings_matrix, train_ratings_matrix))
    test_dataset = tf.data.Dataset.from_tensor_slices((test_ratings_matrix, test_ratings_matrix))

    # Convert datasets to float32, necessary for TensorFlow processing
    train_dataset = train_dataset.map(lambda x, y: (tf.cast(x, tf.float32), tf.cast(y, tf.float32)))
    test_dataset = test_dataset.map(lambda x, y: (tf.cast(x, tf.float32), tf.cast(y, tf.float32)))

    # Shuffle the training dataset with a specified buffer size and batch both datasets
    shuffle_buffer_size = num_users  # Adjust based on available memory
    train_dataset = train_dataset.shuffle(buffer_size=shuffle_buffer_size).batch(batch_size)
    test_dataset = test_dataset.batch(batch_size)

    return num_users, num_movies, train_dataset, test_dataset

# %%
base_path = './data/MovieLens_100K/'  # Adjust this path to where the dataset files are located
batch_size = 64  # Common choice for batch size, but can be adjusted based on memory capacity and model requirements

# Load and preprocess the data
num_users, num_movies, train_dataset, test_dataset = load_and_preprocess_movielens_100k(base_path=base_path, batch_size=batch_size)

# Print out some insights
print(f'Number of users: {num_users}')
print(f'Number of movies: {num_movies}')

# Iterate over the first batch to print its shape and get an insight into the batched dataset
for inputs, targets in train_dataset.take(1):
    print(f'Shape of training data inputs: {inputs.shape}')  # Shape should be (batch_size, num_movies)
    print(f'Shape of training data targets: {targets.shape}')  # Shape should be identical to inputs

for inputs, targets in test_dataset.take(1):
    print(f'Shape of testing data inputs: {inputs.shape}')  # Shape should be (batch_size, num_movies)
    print(f'Shape of testing data targets: {targets.shape}')  # Shape should be identical to inputs
# Out:
# Number of users: 943
# Number of movies: 1682
# Shape of training data inputs: (64, 1682)
# Shape of training data targets: (64, 1682)
# Shape of testing data inputs: (64, 1682)
# Shape of testing data targets: (64, 1682)

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense
import tensorflow.keras.backend as K

def root_mean_squared_error(y_true, y_pred):
    """Define RMSE as a metric."""
    return K.sqrt(K.mean(K.square(y_pred - y_true)))

def build_user_autoencoder(num_movies, encoding_dim=128):
    """
    Build a user-based autoencoder model.
    
    Args:
        num_movies (int): Number of movies in the dataset to set the input dimension.
        encoding_dim (int): Size of the encoding layer, representing the bottleneck.
        
    Returns:
        A compiled Keras Model for the autoencoder.
    """
    # Input layer
    input_layer = Input(shape=(num_movies,), name='Input_Layer')
    
    # Encoder layers
    encoded = Dense(encoding_dim, activation='linear', name='Encoder_Layer')(input_layer)
        
    # Decoder layers
    decoded = Dense(encoding_dim, activation='linear', name='Decoder_Layer')(encoded)
    
    # Output layer
    output_layer = Dense(num_movies, activation='linear', name='Output_Layer')(decoded)
    
    # Define the model
    autoencoder = Model(inputs=input_layer, outputs=output_layer, name='User_Autoencoder')
    
    # Compile the model
    autoencoder.compile(optimizer='adam', loss='mse', metrics=[root_mean_squared_error, 'mae'])
    
    return autoencoder


encoding_dim = 500
autoencoder_model = build_user_autoencoder(num_movies, encoding_dim)

# Display the model summary to check the architecture
autoencoder_model.summary()
# Out:
# Model: "User_Autoencoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input_Layer (InputLayer)    [(None, 1682)]            0
#
#  Encoder_Layer (Dense)       (None, 500)               841500
#
#  Decoder_Layer (Dense)       (None, 500)               250500
#
#  Output_Layer (Dense)        (None, 1682)              842682
#
# =================================================================
# Total params: 1934682 (7.38 MB)
# Trainable params: 1934682 (7.38 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping


early_stopping = EarlyStopping(monitor='val_root_mean_squared_error', patience=5, restore_best_weights=True)

epochs = 1000

# Train the model
history = autoencoder_model.fit(
    train_dataset, 
    validation_data=test_dataset,  
    epochs=epochs,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/1000
# 15/15 [==============================] - 1s 14ms/step - loss: 0.8249 - root_mean_squared_error: 0.8992 - mae: 0.5431 - val_loss: 0.1993 - val_root_mean_squared_error: 0.3111 - val_mae: 0.1708
# Epoch 2/1000
# 15/15 [==============================] - 0s 11ms/step - loss: 0.5028 - root_mean_squared_error: 0.7079 - mae: 0.4081 - val_loss: 0.1688 - val_root_mean_squared_error: 0.2879 - val_mae: 0.1526
# Epoch 3/1000
# 15/15 [==============================] - 0s 11ms/step - loss: 0.3995 - root_mean_squared_error: 0.6308 - mae: 0.3527 - val_loss: 0.1537 - val_root_mean_squared_error: 0.2753 - val_mae: 0.1427
# Epoch 4/1000
# 15/15 [==============================] - 0s 11ms/step - loss: 0.3415 - root_mean_squared_error: 0.5843 - mae: 0.3230 - val_loss: 0.1436 - val_root_mean_squared_error: 0.2669 - val_mae: 0.1375
# Epoch 5/1000
# 15/15 [==============================] - 0s 11ms/step - loss: 0.3027 - root_mean_squared_error: 0.5502 - mae: 0.3049 - val_loss: 0.1364 - val_root_mean_squared_error: 0.2609 - val_mae: 0.1352
# Epoch 6/1000
# 15/15 [==============================] - 0s 11ms/step - loss: 0.2702 - root_mean_squared_error: 0.5201 - mae: 0.2911 - val_loss: 0.1308 - val_root_mean_squared_error: 0.2564 - val_mae: 0.1341
# Epoch 7/1000
# 15/15 [==============================] - 0s 12ms/step - loss: 0.2462 - root_mean_squared_error: 0.4958 - mae: 0.2829 - val_loss: 0.1259 - val_root_mean_squared_error: 0.2524 - val_mae: 0.1327
# Epoch 8/1000
# 15/15 [==============================] - 0s 12ms/step - loss: 0.2204 - root_mean_squared_error: 0.4695 - mae: 0.2720 - val_loss: 0.1214 - val_root_mean_squared_error: 0.2485 - val_mae: 0.1315
# Epoch 9/1000
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1980 - root_mean_squared_error: 0.4452 - mae: 0.2610 - val_loss: 0.1172 - val_root_mean_squared_error: 0.2444 - val_mae: 0.1292
# Epoch 10/1000
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1788 - root_mean_squared_error: 0.4228 - mae: 0.2510 - val_loss: 0.1138 - val_root_mean_squared_error: 0.2410 - val_mae: 0.1280
# Epoch 11/1000
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1635 - root_mean_squared_error: 0.4046 - mae: 0.2423 - val_loss: 0.1107 - val_root_mean_squared_error: 0.2379 - val_mae: 0.1270
# Epoch 12/1000
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1508 - root_mean_squared_error: 0.3885 - mae: 0.2350 - val_loss: 0.1080 - val_root_mean_squared_error: 0.2350 - val_mae: 0.1258
# Epoch 13/1000
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1401 - root_mean_squared_error: 0.3746 - mae: 0.2282 - val_loss: 0.1057 - val_root_mean_squared_error: 0.2326 - val_mae: 0.1248
# Epoch 14/1000
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1309 - root_mean_squared_error: 0.3619 - mae: 0.2217 - val_loss: 0.1035 - val_root_mean_squared_error: 0.2302 - val_mae: 0.1238
# Epoch 15/1000
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1233 - root_mean_squared_error: 0.3513 - mae: 0.2167 - val_loss: 0.1016 - val_root_mean_squared_error: 0.2281 - val_mae: 0.1230
# Epoch 16/1000
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1158 - root_mean_squared_error: 0.3403 - mae: 0.2110 - val_loss: 0.0999 - val_root_mean_squared_error: 0.2264 - val_mae: 0.1221
# Epoch 17/1000
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1095 - root_mean_squared_error: 0.3310 - mae: 0.2063 - val_loss: 0.0983 - val_root_mean_squared_error: 0.2247 - val_mae: 0.1214
# Epoch 18/1000
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1045 - root_mean_squared_error: 0.3233 - mae: 0.2024 - val_loss: 0.0969 - val_root_mean_squared_error: 0.2232 - val_mae: 0.1211
# Epoch 19/1000
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1003 - root_mean_squared_error: 0.3169 - mae: 0.1990 - val_loss: 0.0955 - val_root_mean_squared_error: 0.2218 - val_mae: 0.1207
# Epoch 20/1000
# 15/15 [==============================] - 0s 12ms/step - loss: 0.0964 - root_mean_squared_error: 0.3107 - mae: 0.1955 - val_loss: 0.0943 - val_root_mean_squared_error: 0.2205 - val_mae: 0.1198
# Epoch 21/1000
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0921 - root_mean_squared_error: 0.3034 - mae: 0.1920 - val_loss: 0.0931 - val_root_mean_squared_error: 0.2191 - val_mae: 0.1194
# Epoch 22/1000
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0875 - root_mean_squared_error: 0.2960 - mae: 0.1879 - val_loss: 0.0919 - val_root_mean_squared_error: 0.2179 - val_mae: 0.1188
# Epoch 23/1000
# 15/15 [==============================] - 0s 13ms/step - loss: 0.0837 - root_mean_squared_error: 0.2895 - mae: 0.1843 - val_loss: 0.0910 - val_root_mean_squared_error: 0.2169 - val_mae: 0.1187
# Epoch 24/1000
# 15/15 [==============================] - 0s 12ms/step - loss: 0.0809 - root_mean_squared_error: 0.2846 - mae: 0.1815 - val_loss: 0.0898 - val_root_mean_squared_error: 0.2157 - val_mae: 0.1179
# Epoch 25/1000
# 15/15 [==============================] - 0s 13ms/step - loss: 0.0783 - root_mean_squared_error: 0.2796 - mae: 0.1788 - val_loss: 0.0890 - val_root_mean_squared_error: 0.2149 - val_mae: 0.1178
# Epoch 26/1000
# 15/15 [==============================] - 0s 13ms/step - loss: 0.0765 - root_mean_squared_error: 0.2767 - mae: 0.1772 - val_loss: 0.0882 - val_root_mean_squared_error: 0.2140 - val_mae: 0.1172
# Epoch 27/1000
# 15/15 [==============================] - 0s 12ms/step - loss: 0.0736 - root_mean_squared_error: 0.2713 - mae: 0.1739 - val_loss: 0.0872 - val_root_mean_squared_error: 0.2130 - val_mae: 0.1168
# Epoch 28/1000
# 15/15 [==============================] - 0s 12ms/step - loss: 0.0712 - root_mean_squared_error: 0.2666 - mae: 0.1715 - val_loss: 0.0867 - val_root_mean_squared_error: 0.2125 - val_mae: 0.1168
# Epoch 29/1000
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0696 - root_mean_squared_error: 0.2639 - mae: 0.1699 - val_loss: 0.0858 - val_root_mean_squared_error: 0.2116 - val_mae: 0.1162
# Epoch 30/1000
# 15/15 [==============================] - 0s 13ms/step - loss: 0.0683 - root_mean_squared_error: 0.2614 - mae: 0.1684 - val_loss: 0.0853 - val_root_mean_squared_error: 0.2110 - val_mae: 0.1160
# Epoch 31/1000
# 15/15 [==============================] - 0s 12ms/step - loss: 0.0682 - root_mean_squared_error: 0.2610 - mae: 0.1681 - val_loss: 0.0850 - val_root_mean_squared_error: 0.2110 - val_mae: 0.1161
# Epoch 32/1000
# 15/15 [==============================] - 0s 13ms/step - loss: 0.0668 - root_mean_squared_error: 0.2585 - mae: 0.1673 - val_loss: 0.0841 - val_root_mean_squared_error: 0.2101 - val_mae: 0.1153
# Epoch 33/1000
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0648 - root_mean_squared_error: 0.2546 - mae: 0.1651 - val_loss: 0.0836 - val_root_mean_squared_error: 0.2095 - val_mae: 0.1155
# Epoch 34/1000
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0620 - root_mean_squared_error: 0.2490 - mae: 0.1620 - val_loss: 0.0829 - val_root_mean_squared_error: 0.2087 - val_mae: 0.1150
# Epoch 35/1000
# 15/15 [==============================] - 0s 12ms/step - loss: 0.0602 - root_mean_squared_error: 0.2452 - mae: 0.1598 - val_loss: 0.0824 - val_root_mean_squared_error: 0.2081 - val_mae: 0.1147
# Epoch 36/1000
# 15/15 [==============================] - 0s 12ms/step - loss: 0.0580 - root_mean_squared_error: 0.2407 - mae: 0.1571 - val_loss: 0.0815 - val_root_mean_squared_error: 0.2070 - val_mae: 0.1142
# Epoch 37/1000
# 15/15 [==============================] - 0s 13ms/step - loss: 0.0566 - root_mean_squared_error: 0.2378 - mae: 0.1550 - val_loss: 0.0810 - val_root_mean_squared_error: 0.2064 - val_mae: 0.1139
# Epoch 38/1000
# 15/15 [==============================] - 0s 12ms/step - loss: 0.0549 - root_mean_squared_error: 0.2344 - mae: 0.1533 - val_loss: 0.0805 - val_root_mean_squared_error: 0.2058 - val_mae: 0.1135
# Epoch 39/1000
# 15/15 [==============================] - 0s 12ms/step - loss: 0.0551 - root_mean_squared_error: 0.2345 - mae: 0.1527 - val_loss: 0.0801 - val_root_mean_squared_error: 0.2052 - val_mae: 0.1132
# Epoch 40/1000
# 15/15 [==============================] - 0s 13ms/step - loss: 0.0532 - root_mean_squared_error: 0.2307 - mae: 0.1504 - val_loss: 0.0796 - val_root_mean_squared_error: 0.2046 - val_mae: 0.1128
# Epoch 41/1000
# 15/15 [==============================] - 0s 12ms/step - loss: 0.0524 - root_mean_squared_error: 0.2291 - mae: 0.1495 - val_loss: 0.0792 - val_root_mean_squared_error: 0.2042 - val_mae: 0.1127
# Epoch 42/1000
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0527 - root_mean_squared_error: 0.2294 - mae: 0.1492 - val_loss: 0.0789 - val_root_mean_squared_error: 0.2040 - val_mae: 0.1126
# Epoch 43/1000
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0532 - root_mean_squared_error: 0.2307 - mae: 0.1499 - val_loss: 0.0790 - val_root_mean_squared_error: 0.2042 - val_mae: 0.1129
# Epoch 44/1000
# 15/15 [==============================] - 0s 12ms/step - loss: 0.0536 - root_mean_squared_error: 0.2315 - mae: 0.1510 - val_loss: 0.0786 - val_root_mean_squared_error: 0.2039 - val_mae: 0.1127
# Epoch 45/1000
# 15/15 [==============================] - 0s 12ms/step - loss: 0.0535 - root_mean_squared_error: 0.2315 - mae: 0.1507 - val_loss: 0.0782 - val_root_mean_squared_error: 0.2034 - val_mae: 0.1126
# Epoch 46/1000
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0532 - root_mean_squared_error: 0.2305 - mae: 0.1505 - val_loss: 0.0777 - val_root_mean_squared_error: 0.2030 - val_mae: 0.1122
# Epoch 47/1000
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0515 - root_mean_squared_error: 0.2268 - mae: 0.1485 - val_loss: 0.0774 - val_root_mean_squared_error: 0.2025 - val_mae: 0.1121
# Epoch 48/1000
# 15/15 [==============================] - 0s 12ms/step - loss: 0.0491 - root_mean_squared_error: 0.2215 - mae: 0.1456 - val_loss: 0.0768 - val_root_mean_squared_error: 0.2019 - val_mae: 0.1118
# Epoch 49/1000
# 15/15 [==============================] - 0s 12ms/step - loss: 0.0478 - root_mean_squared_error: 0.2187 - mae: 0.1438 - val_loss: 0.0765 - val_root_mean_squared_error: 0.2015 - val_mae: 0.1115
# Epoch 50/1000
# 15/15 [==============================] - 0s 13ms/step - loss: 0.0475 - root_mean_squared_error: 0.2180 - mae: 0.1435 - val_loss: 0.0761 - val_root_mean_squared_error: 0.2010 - val_mae: 0.1115
# Epoch 51/1000
# 15/15 [==============================] - 0s 12ms/step - loss: 0.0473 - root_mean_squared_error: 0.2175 - mae: 0.1430 - val_loss: 0.0759 - val_root_mean_squared_error: 0.2009 - val_mae: 0.1112
# Epoch 52/1000
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0463 - root_mean_squared_error: 0.2156 - mae: 0.1415 - val_loss: 0.0754 - val_root_mean_squared_error: 0.2004 - val_mae: 0.1110
# Epoch 53/1000
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0461 - root_mean_squared_error: 0.2145 - mae: 0.1411 - val_loss: 0.0754 - val_root_mean_squared_error: 0.2004 - val_mae: 0.1110
# Epoch 54/1000
# 15/15 [==============================] - 0s 12ms/step - loss: 0.0460 - root_mean_squared_error: 0.2146 - mae: 0.1412 - val_loss: 0.0750 - val_root_mean_squared_error: 0.2000 - val_mae: 0.1110
# Epoch 55/1000
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0443 - root_mean_squared_error: 0.2106 - mae: 0.1393 - val_loss: 0.0746 - val_root_mean_squared_error: 0.1996 - val_mae: 0.1108
# Epoch 56/1000
# 15/15 [==============================] - 0s 12ms/step - loss: 0.0431 - root_mean_squared_error: 0.2075 - mae: 0.1371 - val_loss: 0.0744 - val_root_mean_squared_error: 0.1992 - val_mae: 0.1106
# Epoch 57/1000
# 15/15 [==============================] - 0s 12ms/step - loss: 0.0427 - root_mean_squared_error: 0.2065 - mae: 0.1363 - val_loss: 0.0741 - val_root_mean_squared_error: 0.1988 - val_mae: 0.1103
# Epoch 58/1000
# 15/15 [==============================] - 0s 12ms/step - loss: 0.0428 - root_mean_squared_error: 0.2068 - mae: 0.1364 - val_loss: 0.0739 - val_root_mean_squared_error: 0.1986 - val_mae: 0.1104
# Epoch 59/1000
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0418 - root_mean_squared_error: 0.2042 - mae: 0.1348 - val_loss: 0.0734 - val_root_mean_squared_error: 0.1980 - val_mae: 0.1097
# Epoch 60/1000
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0419 - root_mean_squared_error: 0.2046 - mae: 0.1346 - val_loss: 0.0734 - val_root_mean_squared_error: 0.1979 - val_mae: 0.1098
# Epoch 61/1000
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0418 - root_mean_squared_error: 0.2047 - mae: 0.1346 - val_loss: 0.0731 - val_root_mean_squared_error: 0.1975 - val_mae: 0.1098
# Epoch 62/1000
# 15/15 [==============================] - 0s 13ms/step - loss: 0.0426 - root_mean_squared_error: 0.2061 - mae: 0.1355 - val_loss: 0.0730 - val_root_mean_squared_error: 0.1975 - val_mae: 0.1098
# Epoch 63/1000
# 15/15 [==============================] - 0s 12ms/step - loss: 0.0412 - root_mean_squared_error: 0.2034 - mae: 0.1338 - val_loss: 0.0728 - val_root_mean_squared_error: 0.1973 - val_mae: 0.1097
# Epoch 64/1000
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0410 - root_mean_squared_error: 0.2025 - mae: 0.1339 - val_loss: 0.0723 - val_root_mean_squared_error: 0.1968 - val_mae: 0.1094
# Epoch 65/1000
# 15/15 [==============================] - 0s 12ms/step - loss: 0.0408 - root_mean_squared_error: 0.2020 - mae: 0.1339 - val_loss: 0.0722 - val_root_mean_squared_error: 0.1968 - val_mae: 0.1095
# Epoch 66/1000
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0403 - root_mean_squared_error: 0.2006 - mae: 0.1328 - val_loss: 0.0721 - val_root_mean_squared_error: 0.1967 - val_mae: 0.1094
# Epoch 67/1000
# 15/15 [==============================] - 0s 12ms/step - loss: 0.0408 - root_mean_squared_error: 0.2019 - mae: 0.1337 - val_loss: 0.0720 - val_root_mean_squared_error: 0.1967 - val_mae: 0.1093
# Epoch 68/1000
# 15/15 [==============================] - 0s 12ms/step - loss: 0.0398 - root_mean_squared_error: 0.1998 - mae: 0.1320 - val_loss: 0.0717 - val_root_mean_squared_error: 0.1964 - val_mae: 0.1094
# Epoch 69/1000
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0402 - root_mean_squared_error: 0.2005 - mae: 0.1321 - val_loss: 0.0716 - val_root_mean_squared_error: 0.1965 - val_mae: 0.1093
# Epoch 70/1000
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0413 - root_mean_squared_error: 0.2032 - mae: 0.1337 - val_loss: 0.0715 - val_root_mean_squared_error: 0.1964 - val_mae: 0.1092
# Epoch 71/1000
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0412 - root_mean_squared_error: 0.2031 - mae: 0.1335 - val_loss: 0.0715 - val_root_mean_squared_error: 0.1963 - val_mae: 0.1091
# Epoch 72/1000
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0416 - root_mean_squared_error: 0.2038 - mae: 0.1344 - val_loss: 0.0716 - val_root_mean_squared_error: 0.1964 - val_mae: 0.1094
# Epoch 73/1000
# 15/15 [==============================] - 0s 12ms/step - loss: 0.0407 - root_mean_squared_error: 0.2014 - mae: 0.1336 - val_loss: 0.0711 - val_root_mean_squared_error: 0.1958 - val_mae: 0.1087
# Epoch 74/1000
# 15/15 [==============================] - 0s 13ms/step - loss: 0.0393 - root_mean_squared_error: 0.1982 - mae: 0.1313 - val_loss: 0.0708 - val_root_mean_squared_error: 0.1953 - val_mae: 0.1087
# Epoch 75/1000
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0384 - root_mean_squared_error: 0.1957 - mae: 0.1300 - val_loss: 0.0704 - val_root_mean_squared_error: 0.1948 - val_mae: 0.1084
# Epoch 76/1000
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0380 - root_mean_squared_error: 0.1953 - mae: 0.1292 - val_loss: 0.0705 - val_root_mean_squared_error: 0.1949 - val_mae: 0.1085
# Epoch 77/1000
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0395 - root_mean_squared_error: 0.1986 - mae: 0.1302 - val_loss: 0.0704 - val_root_mean_squared_error: 0.1948 - val_mae: 0.1083
# Epoch 78/1000
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0401 - root_mean_squared_error: 0.2001 - mae: 0.1311 - val_loss: 0.0703 - val_root_mean_squared_error: 0.1947 - val_mae: 0.1085
# Epoch 79/1000
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0404 - root_mean_squared_error: 0.2010 - mae: 0.1323 - val_loss: 0.0702 - val_root_mean_squared_error: 0.1946 - val_mae: 0.1085
# Epoch 80/1000
# 15/15 [==============================] - 0s 12ms/step - loss: 0.0392 - root_mean_squared_error: 0.1983 - mae: 0.1313 - val_loss: 0.0698 - val_root_mean_squared_error: 0.1940 - val_mae: 0.1081
# Epoch 81/1000
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0386 - root_mean_squared_error: 0.1967 - mae: 0.1306 - val_loss: 0.0696 - val_root_mean_squared_error: 0.1938 - val_mae: 0.1079
# Epoch 82/1000
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0379 - root_mean_squared_error: 0.1946 - mae: 0.1295 - val_loss: 0.0695 - val_root_mean_squared_error: 0.1938 - val_mae: 0.1080
# Epoch 83/1000
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0383 - root_mean_squared_error: 0.1960 - mae: 0.1298 - val_loss: 0.0693 - val_root_mean_squared_error: 0.1937 - val_mae: 0.1079
# Epoch 84/1000
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0385 - root_mean_squared_error: 0.1961 - mae: 0.1297 - val_loss: 0.0695 - val_root_mean_squared_error: 0.1939 - val_mae: 0.1082
# Epoch 85/1000
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0400 - root_mean_squared_error: 0.1996 - mae: 0.1314 - val_loss: 0.0694 - val_root_mean_squared_error: 0.1940 - val_mae: 0.1082
# Epoch 86/1000
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0393 - root_mean_squared_error: 0.1976 - mae: 0.1307 - val_loss: 0.0693 - val_root_mean_squared_error: 0.1937 - val_mae: 0.1078
# Epoch 87/1000
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0405 - root_mean_squared_error: 0.2008 - mae: 0.1320 - val_loss: 0.0694 - val_root_mean_squared_error: 0.1938 - val_mae: 0.1081
# Epoch 88/1000
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0406 - root_mean_squared_error: 0.2011 - mae: 0.1321 - val_loss: 0.0691 - val_root_mean_squared_error: 0.1934 - val_mae: 0.1077
# Epoch 89/1000
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0398 - root_mean_squared_error: 0.1996 - mae: 0.1316 - val_loss: 0.0689 - val_root_mean_squared_error: 0.1931 - val_mae: 0.1076
# Epoch 90/1000
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0400 - root_mean_squared_error: 0.1997 - mae: 0.1312 - val_loss: 0.0687 - val_root_mean_squared_error: 0.1930 - val_mae: 0.1075
# Epoch 91/1000
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0418 - root_mean_squared_error: 0.2035 - mae: 0.1324 - val_loss: 0.0691 - val_root_mean_squared_error: 0.1933 - val_mae: 0.1077
# Epoch 92/1000
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0407 - root_mean_squared_error: 0.2017 - mae: 0.1324 - val_loss: 0.0687 - val_root_mean_squared_error: 0.1931 - val_mae: 0.1078
# Epoch 93/1000
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0387 - root_mean_squared_error: 0.1966 - mae: 0.1302 - val_loss: 0.0684 - val_root_mean_squared_error: 0.1926 - val_mae: 0.1074
# Epoch 94/1000
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0383 - root_mean_squared_error: 0.1955 - mae: 0.1295 - val_loss: 0.0682 - val_root_mean_squared_error: 0.1923 - val_mae: 0.1071
# Epoch 95/1000
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0378 - root_mean_squared_error: 0.1942 - mae: 0.1289 - val_loss: 0.0682 - val_root_mean_squared_error: 0.1925 - val_mae: 0.1073
# Epoch 96/1000
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0362 - root_mean_squared_error: 0.1904 - mae: 0.1263 - val_loss: 0.0678 - val_root_mean_squared_error: 0.1920 - val_mae: 0.1070
# Epoch 97/1000
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0357 - root_mean_squared_error: 0.1887 - mae: 0.1253 - val_loss: 0.0676 - val_root_mean_squared_error: 0.1917 - val_mae: 0.1069
# Epoch 98/1000
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0345 - root_mean_squared_error: 0.1856 - mae: 0.1236 - val_loss: 0.0675 - val_root_mean_squared_error: 0.1915 - val_mae: 0.1067
# Epoch 99/1000
# 15/15 [==============================] - 0s 12ms/step - loss: 0.0341 - root_mean_squared_error: 0.1844 - mae: 0.1225 - val_loss: 0.0672 - val_root_mean_squared_error: 0.1912 - val_mae: 0.1064
# Epoch 100/1000
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0338 - root_mean_squared_error: 0.1835 - mae: 0.1218 - val_loss: 0.0671 - val_root_mean_squared_error: 0.1909 - val_mae: 0.1063
# Epoch 101/1000
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0327 - root_mean_squared_error: 0.1807 - mae: 0.1202 - val_loss: 0.0669 - val_root_mean_squared_error: 0.1907 - val_mae: 0.1064
# Epoch 102/1000
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0325 - root_mean_squared_error: 0.1799 - mae: 0.1195 - val_loss: 0.0667 - val_root_mean_squared_error: 0.1905 - val_mae: 0.1061
# Epoch 103/1000
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0322 - root_mean_squared_error: 0.1797 - mae: 0.1192 - val_loss: 0.0667 - val_root_mean_squared_error: 0.1904 - val_mae: 0.1061
# Epoch 104/1000
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0329 - root_mean_squared_error: 0.1811 - mae: 0.1198 - val_loss: 0.0668 - val_root_mean_squared_error: 0.1906 - val_mae: 0.1064
# Epoch 105/1000
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0327 - root_mean_squared_error: 0.1808 - mae: 0.1205 - val_loss: 0.0667 - val_root_mean_squared_error: 0.1906 - val_mae: 0.1064
# Epoch 106/1000
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0323 - root_mean_squared_error: 0.1793 - mae: 0.1197 - val_loss: 0.0666 - val_root_mean_squared_error: 0.1906 - val_mae: 0.1062
# Epoch 107/1000
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0327 - root_mean_squared_error: 0.1806 - mae: 0.1200 - val_loss: 0.0665 - val_root_mean_squared_error: 0.1905 - val_mae: 0.1063
# Epoch 108/1000
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0325 - root_mean_squared_error: 0.1805 - mae: 0.1199 - val_loss: 0.0663 - val_root_mean_squared_error: 0.1901 - val_mae: 0.1061
# Epoch 109/1000
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0324 - root_mean_squared_error: 0.1798 - mae: 0.1195 - val_loss: 0.0662 - val_root_mean_squared_error: 0.1899 - val_mae: 0.1059
# Epoch 110/1000
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0325 - root_mean_squared_error: 0.1801 - mae: 0.1198 - val_loss: 0.0663 - val_root_mean_squared_error: 0.1900 - val_mae: 0.1060
# Epoch 111/1000
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0324 - root_mean_squared_error: 0.1800 - mae: 0.1199 - val_loss: 0.0661 - val_root_mean_squared_error: 0.1896 - val_mae: 0.1056
# Epoch 112/1000
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0322 - root_mean_squared_error: 0.1793 - mae: 0.1192 - val_loss: 0.0660 - val_root_mean_squared_error: 0.1895 - val_mae: 0.1056
# Epoch 113/1000
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0316 - root_mean_squared_error: 0.1776 - mae: 0.1186 - val_loss: 0.0659 - val_root_mean_squared_error: 0.1893 - val_mae: 0.1056
# Epoch 114/1000
# 15/15 [==============================] - 0s 12ms/step - loss: 0.0314 - root_mean_squared_error: 0.1770 - mae: 0.1183 - val_loss: 0.0657 - val_root_mean_squared_error: 0.1891 - val_mae: 0.1055
# Epoch 115/1000
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0314 - root_mean_squared_error: 0.1775 - mae: 0.1181 - val_loss: 0.0656 - val_root_mean_squared_error: 0.1889 - val_mae: 0.1053
# Epoch 116/1000
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0317 - root_mean_squared_error: 0.1782 - mae: 0.1184 - val_loss: 0.0655 - val_root_mean_squared_error: 0.1888 - val_mae: 0.1053
# Epoch 117/1000
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0326 - root_mean_squared_error: 0.1802 - mae: 0.1196 - val_loss: 0.0655 - val_root_mean_squared_error: 0.1888 - val_mae: 0.1052
# Epoch 118/1000
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0321 - root_mean_squared_error: 0.1790 - mae: 0.1195 - val_loss: 0.0656 - val_root_mean_squared_error: 0.1890 - val_mae: 0.1054
# Epoch 119/1000
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0313 - root_mean_squared_error: 0.1769 - mae: 0.1180 - val_loss: 0.0653 - val_root_mean_squared_error: 0.1886 - val_mae: 0.1052
# Epoch 120/1000
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0306 - root_mean_squared_error: 0.1749 - mae: 0.1168 - val_loss: 0.0653 - val_root_mean_squared_error: 0.1886 - val_mae: 0.1053
# Epoch 121/1000
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0321 - root_mean_squared_error: 0.1789 - mae: 0.1185 - val_loss: 0.0652 - val_root_mean_squared_error: 0.1887 - val_mae: 0.1052
# Epoch 122/1000
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0318 - root_mean_squared_error: 0.1782 - mae: 0.1187 - val_loss: 0.0651 - val_root_mean_squared_error: 0.1886 - val_mae: 0.1050
# Epoch 123/1000
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0311 - root_mean_squared_error: 0.1763 - mae: 0.1178 - val_loss: 0.0649 - val_root_mean_squared_error: 0.1884 - val_mae: 0.1050
# Epoch 124/1000
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0309 - root_mean_squared_error: 0.1754 - mae: 0.1172 - val_loss: 0.0651 - val_root_mean_squared_error: 0.1886 - val_mae: 0.1050
# Epoch 125/1000
# 15/15 [==============================] - 0s 12ms/step - loss: 0.0312 - root_mean_squared_error: 0.1765 - mae: 0.1177 - val_loss: 0.0649 - val_root_mean_squared_error: 0.1884 - val_mae: 0.1051
# Epoch 126/1000
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0317 - root_mean_squared_error: 0.1778 - mae: 0.1182 - val_loss: 0.0650 - val_root_mean_squared_error: 0.1883 - val_mae: 0.1050
# Epoch 127/1000
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0320 - root_mean_squared_error: 0.1788 - mae: 0.1187 - val_loss: 0.0650 - val_root_mean_squared_error: 0.1885 - val_mae: 0.1050
# Epoch 128/1000
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0309 - root_mean_squared_error: 0.1756 - mae: 0.1174 - val_loss: 0.0648 - val_root_mean_squared_error: 0.1881 - val_mae: 0.1048
# Epoch 129/1000
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0304 - root_mean_squared_error: 0.1743 - mae: 0.1167 - val_loss: 0.0647 - val_root_mean_squared_error: 0.1881 - val_mae: 0.1049
# Epoch 130/1000
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0306 - root_mean_squared_error: 0.1749 - mae: 0.1162 - val_loss: 0.0646 - val_root_mean_squared_error: 0.1879 - val_mae: 0.1046
# Epoch 131/1000
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0313 - root_mean_squared_error: 0.1768 - mae: 0.1177 - val_loss: 0.0646 - val_root_mean_squared_error: 0.1879 - val_mae: 0.1047
# Epoch 132/1000
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0307 - root_mean_squared_error: 0.1755 - mae: 0.1172 - val_loss: 0.0647 - val_root_mean_squared_error: 0.1880 - val_mae: 0.1048
# Epoch 133/1000
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0316 - root_mean_squared_error: 0.1776 - mae: 0.1184 - val_loss: 0.0646 - val_root_mean_squared_error: 0.1880 - val_mae: 0.1048
# Epoch 134/1000
# 15/15 [==============================] - 0s 12ms/step - loss: 0.0315 - root_mean_squared_error: 0.1776 - mae: 0.1183 - val_loss: 0.0646 - val_root_mean_squared_error: 0.1879 - val_mae: 0.1048
# Epoch 135/1000
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0322 - root_mean_squared_error: 0.1789 - mae: 0.1187 - val_loss: 0.0646 - val_root_mean_squared_error: 0.1878 - val_mae: 0.1046
# Epoch 136/1000
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0323 - root_mean_squared_error: 0.1795 - mae: 0.1190 - val_loss: 0.0644 - val_root_mean_squared_error: 0.1876 - val_mae: 0.1044
# Epoch 137/1000
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0315 - root_mean_squared_error: 0.1776 - mae: 0.1178 - val_loss: 0.0643 - val_root_mean_squared_error: 0.1875 - val_mae: 0.1045
# Epoch 138/1000
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0326 - root_mean_squared_error: 0.1805 - mae: 0.1193 - val_loss: 0.0644 - val_root_mean_squared_error: 0.1878 - val_mae: 0.1048
# Epoch 139/1000
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0328 - root_mean_squared_error: 0.1808 - mae: 0.1203 - val_loss: 0.0644 - val_root_mean_squared_error: 0.1878 - val_mae: 0.1048
# Epoch 140/1000
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0320 - root_mean_squared_error: 0.1792 - mae: 0.1192 - val_loss: 0.0642 - val_root_mean_squared_error: 0.1875 - val_mae: 0.1046
# Epoch 141/1000
# 15/15 [==============================] - 0s 12ms/step - loss: 0.0319 - root_mean_squared_error: 0.1787 - mae: 0.1189 - val_loss: 0.0643 - val_root_mean_squared_error: 0.1876 - val_mae: 0.1046
# Epoch 142/1000
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0315 - root_mean_squared_error: 0.1775 - mae: 0.1190 - val_loss: 0.0642 - val_root_mean_squared_error: 0.1874 - val_mae: 0.1047
# Epoch 143/1000
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0313 - root_mean_squared_error: 0.1769 - mae: 0.1184 - val_loss: 0.0640 - val_root_mean_squared_error: 0.1870 - val_mae: 0.1043
# Epoch 144/1000
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0309 - root_mean_squared_error: 0.1757 - mae: 0.1174 - val_loss: 0.0640 - val_root_mean_squared_error: 0.1870 - val_mae: 0.1044
# Epoch 145/1000
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0312 - root_mean_squared_error: 0.1762 - mae: 0.1174 - val_loss: 0.0639 - val_root_mean_squared_error: 0.1868 - val_mae: 0.1041
# Epoch 146/1000
# 15/15 [==============================] - 0s 12ms/step - loss: 0.0305 - root_mean_squared_error: 0.1747 - mae: 0.1159 - val_loss: 0.0636 - val_root_mean_squared_error: 0.1865 - val_mae: 0.1040
# Epoch 147/1000
# 15/15 [==============================] - 0s 12ms/step - loss: 0.0301 - root_mean_squared_error: 0.1728 - mae: 0.1149 - val_loss: 0.0637 - val_root_mean_squared_error: 0.1866 - val_mae: 0.1040
# Epoch 148/1000
# 15/15 [==============================] - 0s 12ms/step - loss: 0.0303 - root_mean_squared_error: 0.1737 - mae: 0.1158 - val_loss: 0.0637 - val_root_mean_squared_error: 0.1865 - val_mae: 0.1040
# Epoch 149/1000
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0293 - root_mean_squared_error: 0.1712 - mae: 0.1147 - val_loss: 0.0635 - val_root_mean_squared_error: 0.1863 - val_mae: 0.1038
# Epoch 150/1000
# 15/15 [==============================] - 0s 13ms/step - loss: 0.0295 - root_mean_squared_error: 0.1716 - mae: 0.1147 - val_loss: 0.0635 - val_root_mean_squared_error: 0.1862 - val_mae: 0.1038
# Epoch 151/1000
# 15/15 [==============================] - 0s 13ms/step - loss: 0.0288 - root_mean_squared_error: 0.1697 - mae: 0.1134 - val_loss: 0.0634 - val_root_mean_squared_error: 0.1861 - val_mae: 0.1038
# Epoch 152/1000
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0287 - root_mean_squared_error: 0.1694 - mae: 0.1136 - val_loss: 0.0634 - val_root_mean_squared_error: 0.1861 - val_mae: 0.1038
# Epoch 153/1000
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0286 - root_mean_squared_error: 0.1690 - mae: 0.1133 - val_loss: 0.0632 - val_root_mean_squared_error: 0.1861 - val_mae: 0.1038
# Epoch 154/1000
# 15/15 [==============================] - 0s 12ms/step - loss: 0.0280 - root_mean_squared_error: 0.1671 - mae: 0.1122 - val_loss: 0.0630 - val_root_mean_squared_error: 0.1858 - val_mae: 0.1035
# Epoch 155/1000
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0280 - root_mean_squared_error: 0.1675 - mae: 0.1121 - val_loss: 0.0629 - val_root_mean_squared_error: 0.1857 - val_mae: 0.1035
# Epoch 156/1000
# 15/15 [==============================] - 0s 12ms/step - loss: 0.0280 - root_mean_squared_error: 0.1671 - mae: 0.1116 - val_loss: 0.0630 - val_root_mean_squared_error: 0.1858 - val_mae: 0.1036
# Epoch 157/1000
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0288 - root_mean_squared_error: 0.1696 - mae: 0.1130 - val_loss: 0.0630 - val_root_mean_squared_error: 0.1859 - val_mae: 0.1036
# Epoch 158/1000
# 15/15 [==============================] - 0s 13ms/step - loss: 0.0283 - root_mean_squared_error: 0.1684 - mae: 0.1124 - val_loss: 0.0630 - val_root_mean_squared_error: 0.1859 - val_mae: 0.1036
# Epoch 159/1000
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0290 - root_mean_squared_error: 0.1701 - mae: 0.1128 - val_loss: 0.0630 - val_root_mean_squared_error: 0.1860 - val_mae: 0.1035
# Epoch 160/1000
# 15/15 [==============================] - 0s 12ms/step - loss: 0.0286 - root_mean_squared_error: 0.1691 - mae: 0.1138 - val_loss: 0.0632 - val_root_mean_squared_error: 0.1862 - val_mae: 0.1039

# %%
# Placeholder for predictions and true ratings
all_predictions = []
all_true_ratings = []

# Iterate through the test dataset to predict ratings
for inputs, targets in test_dataset:
    predictions = autoencoder_model.predict(inputs)
    all_predictions.append(predictions)
    all_true_ratings.append(targets.numpy())

# Concatenate all batched predictions and true ratings
all_predictions = np.concatenate(all_predictions, axis=0)
all_true_ratings = np.concatenate(all_true_ratings, axis=0)

# Filter out unrated items (assuming they are represented by zeros)
rated_indices = np.where(all_true_ratings != 0)
filtered_predictions = all_predictions[rated_indices]
filtered_true_ratings = all_true_ratings[rated_indices]

# Calculate RMSE, MSE, and MAE for rated items
mse = np.mean((filtered_predictions - filtered_true_ratings) ** 2)
rmse = np.sqrt(mse)
mae = np.mean(np.abs(filtered_predictions - filtered_true_ratings))

print(f"Test MSE: {mse}")
print(f"Test RMSE: {rmse}")
print(f"Test MAE: {mae}")
# Out:
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 3ms/step
# Test MSE: 2.1091272830963135
# Test RMSE: 1.452283501625061
# Test MAE: 1.1573264598846436

# %%
import numpy as np

def calculate_ranking_metrics(predictions, true_ratings, k=10, relevance_threshold=4):
    """
    Calculate Precision@K, Recall@K, and NDCG@K with relevance threshold.
    
    Args:
        predictions (np.array): Predicted scores for items, shape (num_users, num_items).
        true_ratings (np.array): True ratings, shape (num_users, num_items).
        k (int): Number of top recommendations to evaluate.
        relevance_threshold (float): Threshold above which items are considered relevant.
        
    Returns:
        dict: Precision@K, Recall@K, and NDCG@K scores averaged across all users.
    """
    precisions, recalls, ndcgs = [], [], []

    # Define a function to calculate DCG; used for both DCG@K and IDCG@K
    def dcg(scores):
        return np.sum((2**scores - 1) / np.log2(np.arange(2, scores.size + 2)))

    for user_predictions, user_true_ratings in zip(predictions, true_ratings):
        # Determine which items are considered relevant for this user
        relevant_items = user_true_ratings > relevance_threshold
        
        # If no items are relevant for this user, skip to avoid zero division
        if not np.any(relevant_items):
            continue
        
        # Rank items based on the predicted scores
        top_k_indices = np.argsort(user_predictions)[-k:][::-1]
        
        # Calculate precision, recall
        num_relevant_in_top_k = np.sum(relevant_items[top_k_indices])
        num_relevant_total = np.sum(relevant_items)
        
        precision_at_k = num_relevant_in_top_k / k
        recall_at_k = num_relevant_in_top_k / num_relevant_total
        
        # Calculate NDCG
        top_k_relevance = relevant_items[top_k_indices].astype(int)
        top_k_dcg = dcg(top_k_relevance)
        ideal_dcg = dcg(np.sort(relevant_items)[-k:][::-1].astype(int))  # Sort by true relevance
        
        ndcg_at_k = top_k_dcg / ideal_dcg if ideal_dcg > 0 else 0
        
        precisions.append(precision_at_k)
        recalls.append(recall_at_k)
        ndcgs.append(ndcg_at_k)
    
    # Calculate the average across all users for whom metrics were computed
    metrics = {
        "Precision@K": np.mean(precisions) if precisions else 0,
        "Recall@K": np.mean(recalls) if recalls else 0,
        "NDCG@K": np.mean(ndcgs) if ndcgs else 0
    }
    
    return metrics

# Example usage:
k = 10
relevance_threshold = 4
metrics = calculate_ranking_metrics(all_predictions, all_true_ratings, k=k, relevance_threshold=relevance_threshold)
print(f"Precision@{k}: {metrics['Precision@K']:.4f}")
print(f"Recall@{k}: {metrics['Recall@K']:.4f}")
print(f"NDCG@{k}: {metrics['NDCG@K']:.4f}")
# Out:
# Precision@10: 0.4988
# Recall@10: 0.7053
# NDCG@10: 0.8224
